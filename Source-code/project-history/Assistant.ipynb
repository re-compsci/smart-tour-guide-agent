# %%
# !pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-1.0.7-cp39-abi3-win_amd64.whl.metadata (7.0 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=1.9 in c:\users\riina\anaconda3\lib\site-packages (from chromadb) (2.8.2)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Using cached chroma_hnswlib-0.7.6.tar.gz (32 kB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting fastapi==0.115.9 (from chromadb)
#   Using cached fastapi-0.115.9-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\riina\anaconda3\lib\site-packages (from chromadb) (1.26.4)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-4.0.0-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\riina\anaconda3\lib\site-packages (from chromadb) (4.13.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Using cached onnxruntime-1.21.1-cp312-cp312-win_amd64.whl.metadata (4.9 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.32.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.32.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Using cached opentelemetry_instrumentation_fastapi-0.53b1-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.32.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\riina\anaconda3\lib\site-packages (from chromadb) (0.21.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached pypika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\riina\anaconda3\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\riina\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Using cached grpcio-1.71.0-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-4.3.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in c:\users\riina\anaconda3\lib\site-packages (from chromadb) (0.9.0)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-32.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\riina\anaconda3\lib\site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\riina\anaconda3\lib\site-packages (from chromadb) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Using cached mmh3-5.1.0-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\riina\anaconda3\lib\site-packages (from chromadb) (3.10.16)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\riina\anaconda3\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\riina\anaconda3\lib\site-packages (from chromadb) (13.7.1)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\riina\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi==0.115.9->chromadb)
#   Using cached starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=19.1 in c:\users\riina\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (25.0)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\riina\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\riina\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.2.0)
# Requirement already satisfied: certifi in c:\users\riina\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\riina\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: idna in c:\users\riina\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: sniffio in c:\users\riina\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\riina\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\riina\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\riina\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\riina\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\riina\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.10.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\riina\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\riina\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Using cached google_auth-2.39.0-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\riina\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\riina\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\riina\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.4.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Using cached durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: protobuf in c:\users\riina\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.3)
# Requirement already satisfied: sympy in c:\users\riina\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Using cached Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in c:\users\riina\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.32.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.32.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.32.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_proto-1.32.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Using cached protobuf-5.29.4-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting opentelemetry-instrumentation-asgi==0.53b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation_asgi-0.53b1-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.53b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation-0.53b1-py3-none-any.whl.metadata (6.8 kB)
# Collecting opentelemetry-semantic-conventions==0.53b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_semantic_conventions-0.53b1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-util-http==0.53b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_util_http-0.53b1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\riina\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.53b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.53b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in c:\users\riina\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\riina\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\riina\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.20.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\riina\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\riina\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\riina\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.30.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\riina\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached httptools-0.6.4-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\riina\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached watchfiles-1.0.5-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\riina\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\riina\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: filelock in c:\users\riina\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\riina\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.12.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\riina\anaconda3\lib\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\riina\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\riina\anaconda3\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\riina\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\riina\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Downloading chromadb-1.0.7-cp39-abi3-win_amd64.whl (18.3 MB)
#    ---------------------------------------- 0.0/18.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/18.3 MB 2.8 MB/s eta 0:00:07
#    --- ------------------------------------ 1.6/18.3 MB 4.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 2.6/18.3 MB 4.7 MB/s eta 0:00:04
#    -------- ------------------------------- 3.9/18.3 MB 5.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 4.7/18.3 MB 4.8 MB/s eta 0:00:03
#    ------------- -------------------------- 6.0/18.3 MB 4.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 7.3/18.3 MB 5.1 MB/s eta 0:00:03
#    ------------------ --------------------- 8.4/18.3 MB 5.0 MB/s eta 0:00:02
#    --------------------- ------------------ 9.7/18.3 MB 5.2 MB/s eta 0:00:02
#    ------------------------ --------------- 11.0/18.3 MB 5.4 MB/s eta 0:00:02
#    --------------------------- ------------ 12.6/18.3 MB 5.6 MB/s eta 0:00:02
#    ------------------------------ --------- 14.2/18.3 MB 5.7 MB/s eta 0:00:01
#    --------------------------------- ------ 15.5/18.3 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  18.1/18.3 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 18.3/18.3 MB 5.7 MB/s eta 0:00:00
# Using cached fastapi-0.115.9-py3-none-any.whl (94 kB)
# Using cached bcrypt-4.3.0-cp39-abi3-win_amd64.whl (152 kB)
# Using cached build-1.2.2.post1-py3-none-any.whl (22 kB)
# Using cached grpcio-1.71.0-cp312-cp312-win_amd64.whl (4.3 MB)
# Using cached kubernetes-32.0.1-py2.py3-none-any.whl (2.0 MB)
# Using cached mmh3-5.1.0-cp312-cp312-win_amd64.whl (41 kB)
# Using cached onnxruntime-1.21.1-cp312-cp312-win_amd64.whl (12.3 MB)
# Using cached opentelemetry_api-1.32.1-py3-none-any.whl (65 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.32.1-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.32.1-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.32.1-py3-none-any.whl (55 kB)
# Using cached opentelemetry_instrumentation_fastapi-0.53b1-py3-none-any.whl (12 kB)
# Using cached opentelemetry_instrumentation-0.53b1-py3-none-any.whl (30 kB)
# Using cached opentelemetry_instrumentation_asgi-0.53b1-py3-none-any.whl (16 kB)
# Using cached opentelemetry_semantic_conventions-0.53b1-py3-none-any.whl (188 kB)
# Using cached opentelemetry_util_http-0.53b1-py3-none-any.whl (7.3 kB)
# Using cached opentelemetry_sdk-1.32.1-py3-none-any.whl (118 kB)
# Downloading posthog-4.0.0-py2.py3-none-any.whl (92 kB)
# Using cached uvicorn-0.34.2-py3-none-any.whl (62 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Using cached durationpy-0.9-py3-none-any.whl (3.5 kB)
# Using cached google_auth-2.39.0-py2.py3-none-any.whl (212 kB)
# Using cached googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Using cached httptools-0.6.4-cp312-cp312-win_amd64.whl (88 kB)
# Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached protobuf-5.29.4-cp310-abi3-win_amd64.whl (434 kB)
# Using cached starlette-0.45.3-py3-none-any.whl (71 kB)
# Using cached watchfiles-1.0.5-cp312-cp312-win_amd64.whl (291 kB)
# Using cached websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Building wheels for collected packages: chroma-hnswlib
#   Building wheel for chroma-hnswlib (pyproject.toml): started
#   Building wheel for chroma-hnswlib (pyproject.toml): finished with status 'done'
#   Created wheel for chroma-hnswlib: filename=chroma_hnswlib-0.7.6-cp312-cp312-win_amd64.whl size=160134 sha256=e8ed0b96640ee83e6b967f43fc7c4241cbe1be2c4bb80dda53b82228164c27b2
#   Stored in directory: c:\users\riina\appdata\local\pip\cache\wheels\28\29\0e\934c768c2e673547ec6e947e821346f4ed691a089fe046743f
# Successfully built chroma-hnswlib
# Installing collected packages: pypika, monotonic, flatbuffers, durationpy, websockets, rsa, pyreadline3, pyproject_hooks, protobuf, opentelemetry-util-http, oauthlib, mmh3, importlib-resources, httptools, grpcio, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, uvicorn, starlette, requests-oauthlib, posthog, opentelemetry-proto, opentelemetry-api, humanfriendly, googleapis-common-protos, google-auth, build, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, kubernetes, fastapi, coloredlogs, opentelemetry-sdk, opentelemetry-instrumentation, onnxruntime, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.0
#     Uninstalling bcrypt-3.2.0:
#       Successfully uninstalled bcrypt-3.2.0
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.3.0 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-1.0.7 coloredlogs-15.0.1 deprecated-1.2.18 durationpy-0.9 fastapi-0.115.9 flatbuffers-25.2.10 google-auth-2.39.0 googleapis-common-protos-1.70.0 grpcio-1.71.0 httptools-0.6.4 humanfriendly-10.0 importlib-resources-6.5.2 kubernetes-32.0.1 mmh3-5.1.0 monotonic-1.6 oauthlib-3.2.2 onnxruntime-1.21.1 opentelemetry-api-1.32.1 opentelemetry-exporter-otlp-proto-common-1.32.1 opentelemetry-exporter-otlp-proto-grpc-1.32.1 opentelemetry-instrumentation-0.53b1 opentelemetry-instrumentation-asgi-0.53b1 opentelemetry-instrumentation-fastapi-0.53b1 opentelemetry-proto-1.32.1 opentelemetry-sdk-1.32.1 opentelemetry-semantic-conventions-0.53b1 opentelemetry-util-http-0.53b1 posthog-4.0.0 protobuf-5.29.4 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 requests-oauthlib-2.0.0 rsa-4.9.1 starlette-0.45.3 uvicorn-0.34.2 watchfiles-1.0.5 websockets-15.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.37.1 requires packaging<25,>=20, but you have packaging 25.0 which is incompatible.
# streamlit 1.37.1 requires pillow<11,>=7.1.0, but you have pillow 11.2.1 which is incompatible.

# %%
from langchain.chains import RetrievalQA
import wikipedia
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAI, OpenAIEmbeddings
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.document_loaders import TextLoader
from langchain_community.utilities import OpenWeatherMapAPIWrapper,WikipediaAPIWrapper

# %%
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

OPENAI_API_KEY  = os.getenv('OPENAI_API_KEY')

# %%
llm = OpenAI(temperature=0)

# %%
#OpenWeatherMap
#weather_api = OpenWeatherMapAPIWrapper()  #https://home.openweathermap.org/api_keys

wiki = wikipedia #WikipediaAPIWrapper()

# %%
from langchain_community.utilities import WikipediaAPIWrapper
from langchain_core.documents import Document
from langchain.text_splitter import CharacterTextSplitter
from langchain.llms import OpenAI  # لو عندك OpenAI أو أي موديل آخر

# 1. تحليل السؤال لاستخراج الموضوع المناسب
def extract_topic(user_input):
    """استخدم موديل LLM بسيط لتحليل النص واستخراج الكلمة المفتاحية."""
 #   llm = OpenAI(temperature=0.3, model_name="gpt-3.5-turbo")
    
    prompt = f"من النص التالي، استخرج الكلمة أو الموضوع الذي أبحث عنه للبحث في ويكيبيديا. لا تشرح، فقط أعطني الكلمة أو الجملة المناسبة:\n\n{user_input}"
    topic = llm.invoke(prompt)
    return topic.strip()

# 2. بحث في ويكيبيديا بناءً على الموضوع المستخرج
def search_wikipedia(user_input):
    #wiki = WikipediaAPIWrapper(top_k_results=3, lang='en')
    
    topic = extract_topic(user_input)  # هنا نحصل على الكلمة أو الفكرة
    print(f"البحث عن: {topic}")
    
    result = wiki.search(topic)
    
    document = Document(page_content=result, metadata={"topic": topic})
    
    text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
    texts = text_splitter.split_documents([document])
    
    return texts

# 📥 مثال استخدام:
user_question = "خطط لي رحلة لعالم ديزني"
texts = search_wikipedia(user_question)

# عرض النتائج:
for i, chunk in enumerate(texts):
    print(f"جزء {i+1} - الموضوع: {chunk.metadata['topic']}")
    print(chunk.page_content)
    print("-" * 80)
# Out:
# البحث عن: عالم ديزني
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[13], line 33
#      31 # 📥 مثال استخدام:
#      32 user_question = "خطط لي رحلة لعالم ديزني"
# ---> 33 texts = search_wikipedia(user_question)
#      35 # عرض النتائج:
#      36 for i, chunk in enumerate(texts):
#
# Cell In[13], line 24, in search_wikipedia(user_input)
#      20 print(f"البحث عن: {topic}")
#      22 result = wiki.search(topic)
# ---> 24 document = Document(page_content=result, metadata={"topic": topic})
#      26 text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
#      27 texts = text_splitter.split_documents([document])
#
# File c:\Users\riina\anaconda3\Lib\site-packages\langchain_core\documents\base.py:289, in Document.__init__(self, page_content, **kwargs)
#     286 """Pass page_content in as positional or named arg."""
#     287 # my-py is complaining that page_content is not defined on the base class.
#     288 # Here, we're relying on pydantic base class to handle the validation.
# --> 289 super().__init__(page_content=page_content, **kwargs)
#
# File c:\Users\riina\anaconda3\Lib\site-packages\langchain_core\load\serializable.py:130, in Serializable.__init__(self, *args, **kwargs)
#     128 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     129     """"""  # noqa: D419
# --> 130     super().__init__(*args, **kwargs)
#
# File c:\Users\riina\anaconda3\Lib\site-packages\pydantic\main.py:193, in BaseModel.__init__(self, **data)
#     191 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     192 __tracebackhide__ = True
# --> 193 self.__pydantic_validator__.validate_python(data, self_instance=self)
#
# ValidationError: 1 validation error for Document
# page_content
#   Input should be a valid string [type=string_type, input_value=[], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type

# %%
# loader = TextLoader(wiki)
# documents = loader.load()
# text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
# texts = text_splitter.split_documents(documents)

# embeddings = OpenAIEmbeddings()
# docsearch = Chroma.from_documents(texts, embeddings, collection_name="sonnets")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\riina\anaconda3\Lib\site-packages\langchain_community\document_loaders\text.py:42, in TextLoader.lazy_load(self)
#      41 try:
# ---> 42     with open(self.file_path, encoding=self.encoding) as f:
#      43         text = f.read()
#
# TypeError: expected str, bytes or os.PathLike object, not WikipediaAPIWrapper
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 2
#       1 loader = TextLoader(wiki)
# ----> 2 documents = loader.load()
#       3 text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
#       4 texts = text_splitter.split_documents(documents)
#
# File c:\Users\riina\anaconda3\Lib\site-packages\langchain_core\document_loaders\base.py:32, in BaseLoader.load(self)
#      30 def load(self) -> list[Document]:
#      31     """Load data into Document objects."""
# ---> 32     return list(self.lazy_load())
#
# File c:\Users\riina\anaconda3\Lib\site-packages\langchain_community\document_loaders\text.py:58, in TextLoader.lazy_load(self)
#      56         raise RuntimeError(f"Error loading {self.file_path}") from e
#      57 except Exception as e:
# ---> 58     raise RuntimeError(f"Error loading {self.file_path}") from e
#      60 metadata = {"source": str(self.file_path)}
#      61 yield Document(page_content=text, metadata=metadata)
#
# RuntimeError: Error loading wiki_client=<module 'wikipedia' from 'c:\\Users\\riina\\anaconda3\\Lib\\site-packages\\wikipedia\\__init__.py'> top_k_results=3 lang='en' load_all_available_meta=False doc_content_chars_max=4000
